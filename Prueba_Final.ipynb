# %%
! pip install git+https://github.com/DianaVG3110/authors_clasiffier
# Out:
# ...
#   Cloning https://github.com/DianaVG3110/authors_clasiffier to /tmp/pip-req-build-q3qi3goc
#   Running command git clone --filter=blob:none --quiet https://github.com/DianaVG3110/authors_clasiffier /tmp/pip-req-build-q3qi3goc
#   Resolved https://github.com/DianaVG3110/authors_clasiffier to commit 87f6cc086e6fe880d3bc9328a61cfa7d2253af77
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import authors_clasiffier as ac
from authors_clasiffier.classify import classify
from authors_clasiffier.resources import *
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
! wget https://raw.githubusercontent.com/DianaVG3110/authors_clasiffier/main/test/camino_de_rosas.txt -P /content/
# Out:
# --2024-01-10 18:31:37--  https://raw.githubusercontent.com/DianaVG3110/authors_clasiffier/main/test/camino_de_rosas.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1538 (1.5K) [text/plain]
# Saving to: ‘/content/camino_de_rosas.txt.1’
#
# camino_de_rosas.txt 100%[===================>]   1.50K  --.-KB/s    in 0s
#
# 2024-01-10 18:31:37 (14.7 MB/s) - ‘/content/camino_de_rosas.txt.1’ saved [1538/1538]

# %%
! wget https://raw.githubusercontent.com/DianaVG3110/authors_clasiffier/main/test/Agradezco.txt -P /content/
# Out:
# --2024-01-10 18:31:27--  https://raw.githubusercontent.com/DianaVG3110/authors_clasiffier/main/test/Agradezco.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2413 (2.4K) [text/plain]
# Saving to: ‘/content/Agradezco.txt’
#
# Agradezco.txt       100%[===================>]   2.36K  --.-KB/s    in 0s
#
# 2024-01-10 18:31:27 (14.9 MB/s) - ‘/content/Agradezco.txt’ saved [2413/2413]

# %%
! wget https://raw.githubusercontent.com/DianaVG3110/authors_clasiffier/main/test/Angel.txt -P /content/
# Out:
# --2024-01-10 18:33:23--  https://raw.githubusercontent.com/DianaVG3110/authors_clasiffier/main/test/Angel.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1709 (1.7K) [text/plain]
# Saving to: ‘/content/Angel.txt’
#
# Angel.txt           100%[===================>]   1.67K  --.-KB/s    in 0s
#
# 2024-01-10 18:33:23 (16.2 MB/s) - ‘/content/Angel.txt’ saved [1709/1709]

# %%
! wget https://raw.githubusercontent.com/DianaVG3110/authors_clasiffier/main/test/Morena.txt -P /content/
# Out:
# --2024-01-10 18:33:26--  https://raw.githubusercontent.com/DianaVG3110/authors_clasiffier/main/test/Morena.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2122 (2.1K) [text/plain]
# Saving to: ‘/content/Morena.txt’
#
# Morena.txt          100%[===================>]   2.07K  --.-KB/s    in 0s
#
# 2024-01-10 18:33:26 (24.4 MB/s) - ‘/content/Morena.txt’ saved [2122/2122]

# %% [markdown]
# ## Clasificaciones positivas

# %%
classify(ae_1, 'camino_de_rosas.txt')

# %%
classify(ae_6, 'Morena.txt')

# %% [markdown]
# ## Clasificaciones negativas

# %%
classify(ae_5, 'Angel.txt')

# %%
classify(ae_4, 'Agradezco.txt')

# %% [markdown]
# ## Análisis de sentimiento

# %%
ac.analysis('camino_de_rosas.txt',language = "spanish")
# Out:
# El sentimiento del texto dado es postivo

# %% [markdown]
# ## Nubes de palabras

# %%
ac.gen_wordcloud('camino_de_rosas.txt')
